# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image

# %% [markdown]
# # Elektrotechnika

# %% [markdown]
# ### Ćwiczenie 1.1
# Pomiar prądu i napięcia
#
# Do obliczeń wykorzystaliśmy prawo Ohma:
#
# **U = I * R**
#
#
# gdzie:
#
# I - natężenie prądu [A] <p>
# U - napięcie produ [V] <p>
# R - rezystancja [Ohm]<p>
#
# Z powyższego wzowu po prostych przekształceniach możemy uzyskać wzory na rezystancję oraz natężenie produ.

# %% [markdown]
# ### Schemat

# %%
path = "./schemat1_1.png"
Image(path)

# %% [markdown]
# ### Tabela pomiarów

# %%
d = {"miernik_Cyfrowy":[0.098, 8.2, 83.67], "miernik_Analogowy": [0.100, 8, 80] }
pomiary = pd.DataFrame(d, index=["I [A]", "U [V]", "R [ohm]"])
pomiary
# Out:
#          miernik_Cyfrowy  miernik_Analogowy
# I [A]              0.098                0.1
# U [V]              8.200                8.0
# R [ohm]           83.670               80.0

# %% [markdown]
# ### Wnioski
# Prąd płynący w obwodzie gdzie napotyka źródło oporu w postaci rezystora. Wydaje się ze pomiary zostały wykonane dla tego samego obwodu. Opór w przypadku miernika cyfrowego wynosi **83[ohm]** zaś w przypadku analogowego **80[ohm]**.<p>
# Symulacja w programie *ElektroSYM* potwierdziła wyniki z powyższej tabeli.<p>
# Według naszego zdania obsługa miernika cyfrowego jest znacznie prostrza w obsłudze. <p>
# Może nie są to skomplikowane pomiary lecz aby minimalizować ryzyko pomyłki sugerowalibyśmy
# używać mierników cyfrowych.
